# %% [markdown]
# # Using information theory to evaluate features

# %% [markdown]
# The mutual information (MI) between a feature and the outcome is a measure of the mutual dependence between the two variables. It extends the notion of correlation to nonlinear relationships. More specifically, it quantifies the information obtained about one random variable through the other random variable.
#
# The concept of MI is closely related to the fundamental notion of entropy of a random variable. Entropy quantifies the amount of information contained in a random variable. Formally, the mutual information—I(X, Y)—of two random variables, X and Y, is defined as the following:
#
# The sklearn function implements feature_selection.mutual_info_regression that computes the mutual information between all features and a continuous outcome to select the features that are most likely to contain predictive information. There is also a classification version (see the documentation for more details).
#
# This notebook contains an application to the financial data we created in Chapter 4, Alpha Factor Research.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.feature_selection import mutual_info_classif

# %%
sns.set_style('whitegrid')
idx = pd.IndexSlice

# %% [markdown]
# ## Get Data

# %% [markdown]
# We use the data produced in [Chapter 4](../../04_alpha_factor_research/00_data/feature_engineering.ipynb).

# %%
with pd.HDFStore('../data/assets.h5') as store:
    data = store['engineered_features']

# %% [markdown]
# ## Create Dummy variables

# %%
dummy_data = pd.get_dummies(data,
                            columns=['year','month', 'msize', 'age',  'sector'],
                            prefix=['year','month', 'msize', 'age', ''],
                            prefix_sep=['_', '_', '_', '_', ''])
dummy_data = dummy_data.rename(columns={c:c.replace('.0', '') for c in dummy_data.columns})
dummy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 328408 entries, ('A', Timestamp('2001-01-31 00:00:00')) to ('UFPI', Timestamp('2018-02-28 00:00:00'))
# Data columns (total 88 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   return_1m              328408 non-null  float64
#  1   return_2m              328408 non-null  float64
#  2   return_3m              328408 non-null  float64
#  3   return_6m              328408 non-null  float64
#  4   return_9m              328408 non-null  float64
#  5   return_12m             328408 non-null  float64
#  6   Mkt-RF                 328408 non-null  float64
#  7   SMB                    328408 non-null  float64
#  8   HML                    328408 non-null  float64
#  9   RMW                    328408 non-null  float64
#  10  CMA                    328408 non-null  float64
#  11  momentum_2             328408 non-null  float64
#  12  momentum_3             328408 non-null  float64
#  13  momentum_6             328408 non-null  float64
#  14  momentum_9             328408 non-null  float64
#  15  momentum_12            328408 non-null  float64
#  16  momentum_3_12          328408 non-null  float64
#  17  return_1m_t-1          326725 non-null  float64
#  18  return_1m_t-2          325042 non-null  float64
#  19  return_1m_t-3          323359 non-null  float64
#  20  return_1m_t-4          321676 non-null  float64
#  21  return_1m_t-5          319993 non-null  float64
#  22  return_1m_t-6          318310 non-null  float64
#  23  target_1m              328408 non-null  float64
#  24  target_2m              326725 non-null  float64
#  25  target_3m              325042 non-null  float64
#  26  target_6m              319993 non-null  float64
#  27  target_12m             309895 non-null  float64
#  28  year_2001              328408 non-null  uint8
#  29  year_2002              328408 non-null  uint8
#  30  year_2003              328408 non-null  uint8
#  31  year_2004              328408 non-null  uint8
#  32  year_2005              328408 non-null  uint8
#  33  year_2006              328408 non-null  uint8
#  34  year_2007              328408 non-null  uint8
#  35  year_2008              328408 non-null  uint8
#  36  year_2009              328408 non-null  uint8
#  37  year_2010              328408 non-null  uint8
#  38  year_2011              328408 non-null  uint8
#  39  year_2012              328408 non-null  uint8
#  40  year_2013              328408 non-null  uint8
#  41  year_2014              328408 non-null  uint8
#  42  year_2015              328408 non-null  uint8
#  43  year_2016              328408 non-null  uint8
#  44  year_2017              328408 non-null  uint8
#  45  year_2018              328408 non-null  uint8
#  46  month_1                328408 non-null  uint8
#  47  month_2                328408 non-null  uint8
#  48  month_3                328408 non-null  uint8
#  49  month_4                328408 non-null  uint8
#  50  month_5                328408 non-null  uint8
#  51  month_6                328408 non-null  uint8
#  52  month_7                328408 non-null  uint8
#  53  month_8                328408 non-null  uint8
#  54  month_9                328408 non-null  uint8
#  55  month_10               328408 non-null  uint8
#  56  month_11               328408 non-null  uint8
#  57  month_12               328408 non-null  uint8
#  58  msize_-1               328408 non-null  uint8
#  59  msize_1                328408 non-null  uint8
#  60  msize_2                328408 non-null  uint8
#  61  msize_3                328408 non-null  uint8
#  62  msize_4                328408 non-null  uint8
#  63  msize_5                328408 non-null  uint8
#  64  msize_6                328408 non-null  uint8
#  65  msize_7                328408 non-null  uint8
#  66  msize_8                328408 non-null  uint8
#  67  msize_9                328408 non-null  uint8
#  68  msize_10               328408 non-null  uint8
#  69  age_0                  328408 non-null  uint8
#  70  age_1                  328408 non-null  uint8
#  71  age_2                  328408 non-null  uint8
#  72  age_3                  328408 non-null  uint8
#  73  age_4                  328408 non-null  uint8
#  74  age_5                  328408 non-null  uint8
#  75  Basic Industries       328408 non-null  uint8
#  76  Capital Goods          328408 non-null  uint8
#  77  Consumer Durables      328408 non-null  uint8
#  78  Consumer Non-Durables  328408 non-null  uint8
#  79  Consumer Services      328408 non-null  uint8
#  80  Energy                 328408 non-null  uint8
#  81  Finance                328408 non-null  uint8
#  82  Health Care            328408 non-null  uint8
#  83  Miscellaneous          328408 non-null  uint8
#  84  Public Utilities       328408 non-null  uint8
#  85  Technology             328408 non-null  uint8
#  86  Transportation         328408 non-null  uint8
#  87  Unknown                328408 non-null  uint8
# dtypes: float64(28), uint8(60)
# memory usage: 90.3+ MB

# %% [markdown]
# ## Mutual Information

# %% [markdown]
# ### Original Data

# %%
target_labels = [f'target_{i}m' for i in [1,2,3,6,12]]
targets = data.dropna().loc[:, target_labels]

features = data.dropna().drop(target_labels, axis=1)
features.sector = pd.factorize(features.sector)[0]

cat_cols = ['year', 'month', 'msize', 'age', 'sector']
discrete_features = [features.columns.get_loc(c) for c in cat_cols]

# %%
mutual_info = pd.DataFrame()
for label in target_labels:
    mi = mutual_info_classif(X=features, 
                             y=(targets[label]> 0).astype(int),
                             discrete_features=discrete_features,
                             random_state=42
                            )
    mutual_info[label] = pd.Series(mi, index=features.columns)

# %%
mutual_info.sum()
# Out:
# target_1m     0.038402
# target_2m     0.062890
# target_3m     0.087285
# target_6m     0.133920
# target_12m    0.201545
# dtype: float64

# %% [markdown]
# ### Normalized MI Heatmap

# %%
fig, ax= plt.subplots(figsize=(15, 4))
sns.heatmap(mutual_info.div(mutual_info.sum()).T, ax=ax, cmap='Blues');

# %% [markdown]
# ### Dummy Data

# %%
target_labels = [f'target_{i}m' for i in [1, 2, 3, 6, 12]]
dummy_targets = dummy_data.dropna().loc[:, target_labels]

dummy_features = dummy_data.dropna().drop(target_labels, axis=1)
cat_cols = [c for c in dummy_features.columns if c not in features.columns]
discrete_features = [dummy_features.columns.get_loc(c) for c in cat_cols]

# %%
mutual_info_dummies = pd.DataFrame()
for label in target_labels:
    mi = mutual_info_classif(X=dummy_features, 
                             y=(dummy_targets[label]> 0).astype(int),
                             discrete_features=discrete_features,
                             random_state=42
                            )    
    mutual_info_dummies[label] = pd.Series(mi, index=dummy_features.columns)

# %%
mutual_info_dummies.sum()
# Out:
# target_1m     0.039540
# target_2m     0.064814
# target_3m     0.089966
# target_6m     0.137832
# target_12m    0.206183
# dtype: float64

# %%
fig, ax= plt.subplots(figsize=(4, 20))
sns.heatmap(mutual_info_dummies.div(mutual_info_dummies.sum()), ax=ax, cmap='Blues');
